# %% [markdown]
# <a href="https://colab.research.google.com/github/milman2/python/blob/pandas/JupyterNotebook/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Test Jupyter Notebook

# %%
print('test')
# Out:
# test
