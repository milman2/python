# %%
import pandas as pd

# %%
df = pd.read_csv('data/seoul_population.csv')
df
# Out:
#     name  population
# 0    종로구      157967
# 1     중구      129797
# 2    용산구      226938
# 3    성동구      306796
# 4    광진구      362304
# 5   동대문구      358141
# 6    중랑구      391668
# 7    성북구      438734
# 8    강북구      309138
# 9    도봉구      328243
# 10   노원구      534096
# 11   은평구      462552
# 12  서대문구      318874
# 13   마포구      368181
# 14   양천구      445591
# 15   강서구      578539
# 16   구로구      433765
# 17   금천구      249344
# 18  영등포구      395286
# 19   동작구      397980
# 20   관악구      510303
# 21   서초구      409491
# 22   강남구      507810
# 23   송파구      638167
# 24   강동구      414231

# %%
# csv로 저장
df.to_csv('temp/sample.csv', index=False)
